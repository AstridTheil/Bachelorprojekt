# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.ascii as ascii
import astropy.io.fits as pyfits
from scipy.ndimage import gaussian_filter
from IPython.display import clear_output
# %matplotlib notebook

# %% [markdown]
# ## Importing data

# %%
t0 = 2457000.0
# TESS data
tess      = pyfits.getdata( 'TESS/gam_psc_tess.fits',1 )
tess_x    = tess['time']
tess_y    = tess['flux']
tt        = np.where( np.isnan( tess_y ) == False )[0]
tess_time = tess_x[tt]
tesstime2 = tess_x[tt]
tess_flux = tess_y[tt]
tessflux2 = tess_y[tt]
#tess_err  = tess['flux_err'][tt]
kk = np.where( (tess_flux < 1.12e7) & (tess_flux > 1.1e7) & (np.abs( tess_flux - np.roll( tess_flux, 1 ))  < 2400 ))[0]  #Bedste TESS
tess_fluxen = 25000.0*((tess_flux[kk] / np.median( tess_flux[kk]))-1)
tess_time   = tess_time[kk]
#tess_err    = ((tess_err[kk] / np.median(tess_flux[kk]))-1)
tess_sort   = np.where((tess_fluxen < 65) & (tess_fluxen > -65))
tess_flux   = tess_fluxen[tess_sort]
tess_time   = tess_time[tess_sort]
tess_sorted = np.where((tess_time < 2454) | (tess_time > 2456.59))  #stregen betyder eller
tess_flux   = tess_flux[tess_sorted]
tess_time   = tess_time[tess_sorted]
#tess_err  = tess_err[tess_sort]

#Her er mærkelig ting ved t 2454

#tess_mask = np.where((tess_flux < 100) & (tess_flux > -100))  #Finder den gode data
#tess_new_time = tess_time[tess_mask]                          #Liste med gode data
#tess_new_flux = tess_flux[tess_mask]                          #Liste med gode data



# SONG OT
ot        = ascii.read( 'SONG/HIP114971_2022-02-02T094858.txt')
time_ot   = ot['col3']-t0
rv_ot     = ot['col5']  #+14480.0
timemask  = np.where(time_ot>2000)   #Finder de data der er samme tid med TESS og Mt Kent
time_ot_masked = time_ot[timemask]   #Liste med kun de data jeg skal bruge
rv_ot_masked   = rv_ot[timemask]     #Liste med kun de data jeg skal bruge
ii = np.where( (time_ot > 2400) & (np.abs( rv_ot - np.roll(rv_ot,1)   ) < 15.0) & (time_ot < 2540))[0]  #Bedste OT data
rv_ot = rv_ot-np.median(rv_ot)

# SONG MtK
mk        = ascii.read( 'SONG/mtkent.txt' )
time_mk   = mk['col1']-t0
rv_mk     = mk['col2']-np.median(rv_ot)
jj = np.where( np.abs( rv_mk - np.roll(rv_mk,1)   ) < 33.0 )[0]  #Bedste Mt Kent data

# %%
cc = np.polyfit(tess_time, tess_flux,2)
tess_flux1 = tess_flux/np.polyval(cc,tess_time)

# %%
tess_time
# Out:
# array([2447.69774541, 2447.69913435, 2447.7005233 , ..., 2472.28983135,
#        2472.29122024, 2472.29260912])

# %%
fig,ax = plt.subplots(1,1,tight_layout=True)
ax.set_xlabel('BJD, 2457000 days subtracted')
ax.set_ylabel('Radial velocities (SONG), Relative flux (TESS)')
#ax.plot(time_ot[ii],gaussian_filter( rv_ot[ii], sigma = 1 ),'o',ms=0.5,label='Teneriffe')
ax.plot(time_mk[jj],rv_mk[jj],'o',ms=0.5, label='Mt Kent')
ax.plot(time_mk[jj],rv_mk_ny,'o',ms = 0.5, label = 'Mt Kent new')
#ax.plot(tess_time,tess_flux,'o',ms=0.5,label='TESS')
#ax.plot(tess_time, np.polyval(cc,tess_time))
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tess_err
# Out:
# array([-0.9999683 , -0.9999683 , -0.9999683 , ..., -0.9999662 ,
#        -0.99996614, -0.9999661 ], dtype=float32)

# %%
tess
# Out:
# FITS_rec([(2447.69080068, 11022467., 350.87793, 994.95575858, 199.70104802, 0),
#           (2447.69218963, 11178857., 353.3844 , 994.94609139, 199.69025426, 0),
#           (2447.69357857, 11179504., 353.39627, 994.94346699, 199.70093313, 0),
#           ...,
#           (2473.16205374,       nan,       nan,          nan,          nan, 0),
#           (2473.16344263,       nan,       nan,          nan,          nan, 0),
#           (2473.16483152,       nan,       nan,          nan,          nan, 0)],
#          dtype=(numpy.record, [('TIME', '>f8'), ('FLUX', '>f4'), ('FLUX_ERR', '>f4'), ('MOM_CENTR1', '>f8'), ('MOM_CENTR2', '>f8'), ('QUALITY', '>i4')]))

# %%
np.min(time_ot)+2457000
# Out:
# 2458586.75765543

# %%
pyfits.info('TESS/gam_psc_tess.fits')
# Out:
# Filename: TESS/gam_psc_tess.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   ()
#   1  LIGHTCURVE    1 BinTableHDU     26   18342R x 6C   [D, E, E, D, D, J]

# %%
tess
# Out:
# FITS_rec([(2447.69080068, 11022467., 350.87793, 994.95575858, 199.70104802, 0),
#           (2447.69218963, 11178857., 353.3844 , 994.94609139, 199.69025426, 0),
#           (2447.69357857, 11179504., 353.39627, 994.94346699, 199.70093313, 0),
#           ...,
#           (2473.16205374,       nan,       nan,          nan,          nan, 0),
#           (2473.16344263,       nan,       nan,          nan,          nan, 0),
#           (2473.16483152,       nan,       nan,          nan,          nan, 0)],
#          dtype=(numpy.record, [('TIME', '>f8'), ('FLUX', '>f4'), ('FLUX_ERR', '>f4'), ('MOM_CENTR1', '>f8'), ('MOM_CENTR2', '>f8'), ('QUALITY', '>i4')]))

# %%
np.max(tess['QUALITY'])
# Out:
# 0

# %%
delta= x-(np.roll(x,1)+np.roll(x,-1))*1/2 #til at sortere i data

x_coni = x_i -1/2*(x_iminus1+x_iplus1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0a903c9b86a1> in <module>
# ----> 1 delta= x-(np.roll(x,1)+np.roll(x,-1))*1/2 #til at sortere i data
#       2
#       3 x_coni = x_i -1/2*(x_iminus1+x_iplus1)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Plot errorbars - er i datasættene

# %%
def power(time, signal, esignal, freqmin, freqmax, nfreq):
    """
    time: time for each observation
    signal: velocity (SONG) or magnitude (TESS)
    esignal: Error on signal
    freqmin: minimum frequency
    freqmax: maximum frequency
    nfreq: number of frequencies in [freqmin, freqmax] interval
    """
    fs  = np.linspace(freqmin,freqmax,nfreq)     #Her laves den cykliske frekvens
    nu  = 2*np.pi*fs                             #Her laves den angulære frekvens
    t   = time                                   #Sekunder siden tidseriens start
    signal = signal - np.median(signal)
    wt = 1/(esignal**2)
    
    alphas = np.zeros(len(fs))
    betas  = np.zeros(len(fs))
    
    Ps = np.zeros(len(fs))
    
    imax_fs = len(fs)
    
    for (i,f) in enumerate(fs):
        vt = nu[i]*t
        s  = np.sum(wt*signal*np.sin(vt))
        c  = np.sum(wt*signal*np.cos(vt))
        ss = np.sum(wt*np.sin(vt)**2)
        cc = np.sum(wt*np.cos(vt)**2)
        sc = np.sum(wt*np.sin(vt)*np.cos(vt))       
        
        alpha = (s*cc-c*sc)/(ss*cc-sc**2)
        beta  = (c*ss-s*sc)/(ss*cc-sc**2)
    
        P = alpha**2 + beta**2
        
        alphas[i] = alpha
        betas[i]  = beta
        Ps[i]     = P
    
    return Ps, fs, alphas, betas

# %%
def clean(signal, time, alpha, beta, P,frekvens,nfrekvens,f_init,f_max,nfreq):
    """
    signal: original data, radialhastighed (SONG) eller flux (TESS)
    time: tiden
    alpha: originale alpha
    beta: originale beta
    P: originale power
    frekvens: originale frekvens
    nfrekvens: antal gange en frekvens skal trækkes fra
    f_init: initial frequency
    f_max: max frequency
    nfreq: number of frequencies in [freqmin, freqmax] interval
    """
    
    output_list = []
    
    for _ in range(nfrekvens):
        P_max_test = np.where(P == np.max(P))
        alpha_max  = alpha[P_max_test][0]
        beta_max   = beta[P_max_test][0]
        f0         = frekvens[P_max_test][0]
        signal     = signal - alpha_max * np.sin(2 * np.pi * f0 * time) - beta_max * np.cos(2 * np.pi * f0 * time)
        
        P,frekvens,alpha,beta = power(time, signal,1,f_init,f_max,nfreq)
        
        output = {
            'signals': signal,
            'Ps': P,
            'fs': frekvens,
            'alphas': alpha,
            'betas': beta,
        }
        
        output_list.append(output)
    
    
    
    return output_list
    
    #Tilføj f0 i output

# %% [markdown]
# ## Testing the power function

# %%
time = np.linspace(0,200,10000)
signal = np.sin(3*time)+np.sin(5*time)+np.sin(7*time)

# %%
time1 = np.array([time[0:4000],time[6000:10000]]).flatten()
time1.shape
signal1 = np.array([signal[0:4000],signal[6000:10000]]).flatten()

# %%
fig2,ax2 = plt.subplots(1,1)
ax2.plot(time, signal)
#ax2.plot(time1,signal1)
ax2.plot(time, cleaning[0]['signals'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
time = time-np.median(time)
P,f,a,b = power(time,signal,1,2/(2*np.pi),10/(2*np.pi),1000)
#P1,f1,a1,b1 = power(time1,signal1,1,2/(2*np.pi),10/(2*np.pi),1000)

# %%
cleaning = clean(signal,time,a,b,P,f,3,2/(2*np.pi),10/(2*np.pi),1000)

# %%
P_max_test = np.where(P == np.max(P))
a_max = a[P_max_test][0]
b_max = b[P_max_test][0]
f0 = f[P_max_test][0]
signal_ny = signal - a_max * np.sin(2 * np.pi * f0 * time) - b_max * np.cos(2 * np.pi * f0 * time)

# %%
P1,f1,a1,b1 = power(time,signal_ny,1,2/(2*np.pi),10/(2*np.pi),1000)

# %%
P_max_test1 = np.where(P1 == np.max(P1))
a_max1 = a1[P_max_test1][0]
b_max1 = b1[P_max_test1][0]
f1_ny = f1[P_max_test1][0]
signal_ny1 = signal_ny - a_max1 * np.sin(2 * np.pi * f1_ny * time) - b_max1 * np.cos(2 * np.pi * f1_ny * time)

P2,f2,a2,b2 = power(time,signal_ny1,1,2/(2*np.pi),10/(2*np.pi),1000)

# %%
fig3,ax3 = plt.subplots(1,1)
ax3.plot(2*np.pi*f,P, label = 'gammel')
ax3.plot(2*np.pi*cleaning[0]['fs'],cleaning[0]['Ps'], label = '1st clean')
ax3.plot(2*np.pi*cleaning[1]['fs'],cleaning[1]['Ps'], label = '2nd clean')
ax3.plot(2*np.pi*cleaning[2]['fs'],cleaning[2]['Ps'], label = '3rd clean')
#ax3.plot(2*np.pi*f1,P1,alpha=0.5, label = 'ny')
#ax3.plot(2*np.pi*f2,P2,alpha=0.5, label = 'ny2')
#ax3.plot(time,signal)
ax3.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Making the powerspectra for the data

# %%
tessf_Nq = (4*(tess_time[-1]-tess_time[0])*24*60*60)**(-1)
otf_Nq   = (4*(time_ot[ii][-1]-time_ot[ii][0])*24*60*60)**(-1)
mkf_Nq   = (4*(time_mk[jj][-1]-time_mk[jj][0])*24*60*60)**(-1)

f_init   = 1e-10

# %% [markdown]
# #### Teneriffe

# %%
cc     = np.polyfit( time_ot[ii], rv_ot[ii], 2 )
xx1    = 86400.0 * (time_ot[ii] - np.median(time_ot[ii]))
yy1    = rv_ot[ii] - np.polyval( cc, time_ot[ii])
erv1   = 0.0*yy1 + 1.0
fmin   = 0.0
fmax   = 500.0 / 1e6
npt    = 20000

P_ot,f_ot,a_ot,b_ot            = power(xx1,yy1,erv1,1e-6,fmax,20000)

# %%
ot_clean = clean(yy1,xx1,a_ot,b_ot,P_ot,f_ot,10,1e-6, fmax, 20000)

# %%
ot_clean[0]['fs']

# %%
fig4,ax4 = plt.subplots(1,1)
#ax4.plot(f_ot*1e6,P_ot, label = 'Original', alpha =0.5)
#ax4.plot(ot_clean[0]['fs']*1e6,ot_clean[0]['Ps'], label = '1st clean', alpha = 0.5)
ax4.plot(ot_clean[-1]['fs']*1e6,ot_clean[-1]['Ps'], label = 'last clean', alpha = 0.5)
ax4.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Mt Kent

# %%
cc_mk    = np.polyfit( time_mk[jj], rv_mk[jj], 2 )
xx_mk    = 86400.0 * (time_mk[jj] - np.median(time_mk[jj]))
yy_mk    = rv_mk[jj] - np.polyval( cc_mk, time_mk[jj])
erv_mk   = 0.0*yy_mk + 1.0
npt      = 20000

P_mk,f_mk,a_mk,b_mk = power(xx_mk,yy_mk,erv_mk,f_init,200*1e-6,npt)

# %%
fig,ax8 = plt.subplots(1,1)
#ax8.plot(xx_mk,rv_mk[jj])
#ax8.plot(xx_mk, np.polyval(cc_mk, time_mk[jj]))
#ax8.plot(xx_mk,rv_mk[jj]-np.polyval(cc_mk,time_mk[jj]))
ax8.plot(xx_mk,yy_mk)
ax8.plot(xx_mk,rv_mk_ny, 'r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
P_max0 = np.where(P_mk == np.max(P_mk))
a_max = a_mk[P_max0][0]
b_max = b_mk[P_max0][0]
f0 = f_mk[P_max0][0]
rv_mk_ny = yy_mk - a_max * np.sin(2 * np.pi * f0 * xx_mk) - b_max * np.cos(2 * np.pi * f0 * xx_mk)

# %%
a_max,b_max,f0*1e6,P_max0, xx_mk[4]
# Out:
# (9.121905673621677,
#  -1.0057930962642347,
#  26.801426666333313,
#  (array([2680]),),
#  -527908.5878536105)

# %%
#cc_mk    = np.polyfit( time_mk[jj], rv_mk_ny, 2 )  #hvis den er med fjernes den første meget store
#xx_mk_ny    = 86400.0 * time_mk[jj]
yy_mk0    = rv_mk_ny #- np.polyval( cc_mk, time_mk[jj])
erv_mk   = 0.0*yy_mk0 + 1.0

P_mk_ny,f_mk_ny,a_mk_ny,b_mk_ny = power(xx_mk,yy_mk0,erv_mk,1e-6,200*1e-6,npt)

# %%
a_mk_ny[2680],b_mk_ny[2680], xx_mk[4],xx_mk[5],f_mk_ny[2680]*1e6
# Out:
# (6.272558404259866,
#  7.457485941574934,
#  -527908.5878536105,
#  -527723.8992154598,
#  26.801426666333313)

# %%
P_max1 = np.where(P_mk_ny == np.max(P_mk_ny))
a_max1 = a_mk_ny[P_max1][0]
b_max1 = b_mk_ny[P_max1][0]
f1 = f_mk_ny[P_max1][0]  #find hvor power er størst
rv_mk1 = rv_mk_ny - a_max1 * np.sin(2 * np.pi * f1 * xx_mk) - b_max1 * np.cos(2 * np.pi * f1 * xx_mk)

# %%
f1*1e6
# Out:
# 37.43195287764387

# %%
#cc_mk    = np.polyfit( time_mk[jj], rv_mk1, 2 )
#xx_mk    = 86400.0 * time_mk[jj]   #ensformig alle
yy_mk1    = rv_mk1
erv_mk   = 0.0*yy_mk + 1.0

P_mk1,f_mk1,a_mk1,b_mk1 = power(xx_mk,yy_mk1,erv_mk,f_init,200*1e-6,npt)

# %%
mk_clean = clean(yy_mk, xx_mk, a_mk, b_mk, P_mk, f_mk, 4, 1e-6,200*1e-6,npt)

# %%
len(mk_clean[0]['fs'])
# Out:
# 20000

# %%
fig,ax5 = plt.subplots(1,1)
ax5.set_ylim(0,100)
ax5.plot(f_mk*1e6,P_mk,alpha = 0.5, label = 'Original')
#ax5.plot(f_mk_ny*1e6,P_mk_ny, alpha = 0.5, label = 'f0')
#ax5.plot(f_mk1*1e6,P_mk1, alpha = 0.5, label = 'f1')
ax5.plot(mk_clean[0]['fs']*1e6,mk_clean[0]['Ps'], alpha=0.5,label = '1st clean')
ax5.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### SONG combined

# %%
xx2  = np.append( xx_mk, xx1 )
yy2  = np.append( yy_mk, yy1 )
erv2 = 0.0 * yy2 + 1.0

P_SONG,f_SONG,a_SONG,b_SONG = power(xx2,yy2,erv2,f_init,fmax,npt)

# %%
fig,ax6 = plt.subplots(1,1)
ax6.plot(f_SONG*1e6,P_SONG)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### TESS

# %%
xt     = tess_time
yt     = ((tess_flux / np.median( tess_flux))-1)
tt     = np.where( (np.abs( yt - np.roll( yt,1) ) < 0.0003) & (yt - gaussian_filter( yt, sigma=3) < 0.0002 ) )[0]
tt     = np.where( (np.abs( yt - np.roll( yt,1) ) < 0.0003) & (yt - gaussian_filter( yt, sigma=3) < 0.0002 ) & ( ( xt < 2453.7) | (xt > 2455.5) ) )[0]
time   = xt[tt]
mag    = 10.0 - 2.5 * np.log10( yt[tt] + 1)

cc_TESS = np.polyfit( time, mag, 2 )
fitmag  = np.polyval( cc_TESS, time )

P_TESS, f_TESS, a_TESS, b_TESS = power( 86400.0 * time, mag - fitmag, 0.0*mag+1.0, 0, 0.0005, 20000 )
# Out:
# /Users/astridtheil/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log10
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-43-c330c21c5a14> in <module>
#       6 mag    = 10.0 - 2.5 * np.log10( yt[tt] +1 )
#       7
# ----> 8 cc_TESS = np.polyfit( time, mag, 2 )
#       9 fitmag  = np.polyval( cc_TESS, time )
#      10
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     629     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     630     lhs /= scale
# --> 631     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     632     c = (c.T/scale).T  # broadcast scale coefficients
#     633
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ...

# %%
time = tess_time
mag = 10.0-2.5*np.log10(tess_flux + 1)
cc_TESS = np.polyfit( time, mag, 2 )
fitmag  = np.polyval( cc_TESS, time )

P_TESS, f_TESS, a_TESS, b_TESS = power( 86400.0 * time, mag - fitmag, 0.0*mag+1.0, 0, 0.0005, 20000 )
# Out:
# /Users/astridtheil/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-40-d3aa3ddba397> in <module>
#       1 time = tess_time
#       2 mag = 10.0-2.5*np.log10(tess_flux + 1)
# ----> 3 cc_TESS = np.polyfit( time, mag, 2 )
#       4 fitmag  = np.polyval( cc_TESS, time )
#       5
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     629     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     630     lhs /= scale
# --> 631     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     632     c = (c.T/scale).T  # broadcast scale coefficients
#     633
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ...

# %%
mag
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)

# %%
xt     = tess_time
yt     = ((tess_flux1 / np.median( tess_flux1))-1)
tt     = np.where( (np.abs( yt - np.roll( yt,1) ) < 0.0003) & (yt - gaussian_filter( yt, sigma=3) < 0.0002 ) )[0]
tt     = np.where( (np.abs( yt - np.roll( yt,1) ) < 0.0003) & (yt - gaussian_filter( yt, sigma=3) < 0.0002 ) & ( ( xt < 2453.7) | (xt > 2455.5) ) )[0]
time   = xt[tt]
mag    = 10.0 - 2.5 * np.log10( yt[tt] +1 )

cc_TESS = np.polyfit( time, mag, 2 )
fitmag  = np.polyval( cc_TESS, time )

P_TESS1, f_TESS1, a_TESS1, b_TESS1 = power( 86400.0 * time, mag - fitmag, 0.0*mag+1.0, 0, 0.0005, 20000 )
# Out:
# /Users/astridtheil/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log10
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-165-e73c5e71ac0e> in <module>
#       6 mag    = 10.0 - 2.5 * np.log10( yt[tt] +1 )
#       7
# ----> 8 cc_TESS = np.polyfit( time, mag, 2 )
#       9 fitmag  = np.polyval( cc_TESS, time )
#      10
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     629     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     630     lhs /= scale
# --> 631     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     632     c = (c.T/scale).T  # broadcast scale coefficients
#     633
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ...

# %%
fig,ax6 = plt.subplots(1,1)
ax6.plot(f_TESS*1e6,P_TESS)
ax6.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
